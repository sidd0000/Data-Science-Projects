# %%
import numpy as np
import pandas as pd  
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %load_ext autoreload
# %autoreload

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
sns.distplot(crash_df['not_distracted'])
# Out:
# C:\Users\Siddhesh\AppData\Local\Temp\ipykernel_20752\1417402792.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(crash_df['not_distracted'])
# <Axes: xlabel='not_distracted', ylabel='Density'>

# %%
sns.distplot(crash_df['not_distracted'])
# Out:
# C:\Users\Siddhesh\AppData\Local\Temp\ipykernel_20752\1417402792.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(crash_df['not_distracted'])
# <Axes: xlabel='not_distracted', ylabel='Density'>

# %%
new_Crash_df=crash_df.head(7)
new_Crash_df
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
# 5   13.6     5.032    3.808          10.744       12.920       835.50
# 6   10.8     4.968    3.888           9.396        8.856      1068.73
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA
# 5      139.91     CO
# 6      167.02     CT

# %%
sns.distplot(new_Crash_df['not_distracted'])
# Out:
# C:\Users\Siddhesh\AppData\Local\Temp\ipykernel_20752\2141865623.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_Crash_df['not_distracted'])
# <Axes: xlabel='not_distracted', ylabel='Density'>

# %%
sns.distplot(crash_df['not_distracted'],kde=False,bins=21)
# Out:
# C:\Users\Siddhesh\AppData\Local\Temp\ipykernel_20752\4127915814.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(crash_df['not_distracted'],kde=False,bins=21)
# <Axes: xlabel='not_distracted'>

# %%
sns.jointplot(data=crash_df,kind='hex')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sns.jointplot(data=crash_df,kind='hex')
#
# File c:\Python312\Lib\site-packages\seaborn\axisgrid.py:2313, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2311 joint_kws.setdefault("gridsize", gridsize)
#    2312 joint_kws.setdefault("cmap", cmap)
# -> 2313 grid.plot_joint(plt.hexbin, **joint_kws)
#    2315 marginal_kws.setdefault("kde", False)
#    2316 marginal_kws.setdefault("color", color)
#
# File c:\Python312\Lib\site-packages\seaborn\axisgrid.py:1834, in JointGrid.plot_joint(self, func, **kwargs)
#    1832     func(x=self.x, y=self.y, **kwargs)
#    1833 else:
# -> 1834     func(self.x, self.y, **kwargs)
#    1836 return self
#
# ...

# %%
plt.style.use('ggplot')
sns.jointplot(x='speeding',y='alcohol',data=crash_df,kind='kde')

# %%
sns.kdeplot(crash_df['alcohol'])
# Out:
# <Axes: xlabel='alcohol', ylabel='Density'>

# %%
sns.pairplot(crash_df)
plt.tight_layout()
plt.savefig('ok.png')

# %%
ok=pd.read_csv('ComputerSales.csv')
sns.pairplot(ok)

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
op=sns.load_dataset('tips')

# %%
sns.pairplot(op,hue='sex',palette='Blues')

# %% [markdown]
# RUG PLOT

# %%
sns.rugplot(op['tip'])
# Out:
# <Axes: xlabel='tip'>

# %%
sns.set_style('ticks')

plt.figure(figsize=(8,4))
sns.jointplot(x='speeding',y='alcohol',data=crash_df,kind='reg')
sns.set_context('paper',font_scale=1.6)
sns.despine(left=True,bottom=True,right=True,top=True)

# %%
sns.barplot(x='sex',y='total_bill',data=op,estimator=np.var)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(x='sex',data=op,order=None)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.boxplot(x='day',y='total_bill',data=op,hue='sex')
plt.legend()

# %%
sns.violinplot(data=op,x='day',y='total_bill',hue='sex',split=True)
plt.legend(loc=0)

# %%
sns.stripplot(x='day',y='total_bill',data=op,hue='sex',jitter=True,dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day',y='total_bill',data=op)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize=(8,6))
sns.set_style('darkgrid')
sns.set_context('talk',font_scale=1.4)
sns.stripplot(x='day',y='total_bill',data=op,hue='sex',jitter=True,dodge=True,palette='afmhot')
plt.legend()

# %%
crash_df
c=crash_df.drop(columns=['abbrev'])
c_m=c.corr()
sns.heatmap(c_m,annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
flights=sns.load_dataset('flights')
flights=flights.pivot_table(index='month',columns='year',values='passengers')
sns.heatmap(flights,cmap='Blues',linecolor='white',linewidth=2)
plt.legend()
# Out:
# C:\Users\Siddhesh\AppData\Local\Temp\ipykernel_20752\2430358034.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flights=flights.pivot_table(index='month',columns='year',values='passengers')
# C:\Users\Siddhesh\AppData\Local\Temp\ipykernel_20752\2430358034.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
iris=sns.load_dataset('iris')

species=iris.pop('species')
iris.head(3)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
sns.clustermap(iris)

# %%
flights=sns.load_dataset('flights')
flights= flights.pivot(index='month',columns='year',values='passengers')

sns.clustermap(flights,standard_scale=2,cmap='Blues')

# %%
plt.style.use('default')
iris=sns.load_dataset('iris')
iris_g=sns.PairGrid(iris,hue='species')
iris_g.map_diag(plt.hist)
# iris_g.map_offdiag(plt.scatter)  
iris_g.map_upper(plt.scatter)
iris_g.map_lower(sns.kdeplot)

# %%
tips = sns.load_dataset('tips')

# Create the FacetGrid
g = sns.FacetGrid(tips, col='time', row='smoker')

# Map a scatter plot to the grid
g.map(sns.scatterplot, 'total_bill', 'tip')

# Show the plot
plt.show()

# %%
print(op)

# %%
act_tf=sns.load_dataset('attention')

# %%
act_fg=sns.FacetGrid(act_tf,col='subject',col_wrap=5,height=1.5)
act_fg.map(plt.plot,'solutions','score',marker='.')

# %%
plt.figure(figsize=(8,6))
sns.set_context('paper',font_scale=1.4)
sns.lmplot(x='total_bill',y='tip',hue='sex',data=tips,markers=['o','^'],scatter_kws={'s':100,'linewidths':2,'edgecolor':'w'})

# %%
sns.lmplot(x='total_bill',y='tip',col='sex',row='time',data=tips,height=8,aspect=0.65)
sns.set_context('paper',font_scale=1.4)

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# setting the max parameter to 1, will return a list with 2 elements!

import seaborn as sns 
ok=sns.load_dataset('')
sns.violinplot(ok)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 4
#       1 # setting the max parameter to 1, will return a list with 2 elements!
#       3 import seaborn as sns
# ----> 4 ok=sns.load_dataset('ComputerSales.csv')
#       5 sns.violinplot(ok)
#
# File c:\Python312\Lib\site-packages\seaborn\utils.py:573, in load_dataset(name, cache, data_home, **kws)
#     571 if not os.path.exists(cache_path):
#     572     if name not in get_dataset_names():
# --> 573         raise ValueError(f"'{name}' is not one of the example datasets.")
#     574     urlretrieve(url, cache_path)
#     575 full_path = cache_path
#
# ValueError: 'ComputerSales.csv' is not one of the example datasets.
